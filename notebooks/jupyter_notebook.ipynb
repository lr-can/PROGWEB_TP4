# %% [markdown]
# # Importations

# %%
import requests

# %% [markdown]
# # Première request `get`

# %%
resp = requests.get("http://localhost:5000/api/demo")
resp.json()
# Out:
# {'AA': 124}

# %% [markdown]
# ### Qu'est-ce qu'il se passe sous le capot ?
# Eh bien à une époque c'était ✨magique✨. Mais en vrai ça c'est concrètement ce qu'on a lorsque l'on réalise une requête à une API Web.

# %% [markdown]
# # TP7 - API Web
# ## `/api/genes/<gene_id>`
# ### Error 404 case

# %%
resp_error = requests.get("http://localhost:5000/api/genes/UNKNOWNGENE")
print(resp_error.status_code)  # Should be 404
resp_error.json()  # Should contain error message
# Out:
# 404
# {'error': 'Gene not found'}

# %% [markdown]
# ### Regular results

# %%
resp_regular = requests.get("http://localhost:5000/api/genes/ENSG00000139618")
print(resp_regular.status_code)  # Should be 200
resp_regular.json()  # Should contain gene information
# Out:
# 200
# {'Associated_Gene_Name': 'BRCA2',
#  'Band': 'q13.1',
#  'Chromosome_Name': '13',
#  'Ensembl_Gene_ID': 'ENSG00000139618',
#  'Gene_End': 32973805,
#  'Gene_Start': 32889611,
#  'Strand': 1,
#  'Transcript_count': 6,
#  'href': '/api/genes/ENSG00000139618',
#  'parts': ['skin',
#   'atrioventricular node',
#   'superior cervical ganglion',
#   'appendix',
#   'trigeminal ganglion'],
#  'transcript': [{'Ensembl_Gene_ID': 'ENSG00000139618',
#    'Ensembl_Transcript_ID': 'ENST00000380152',
#    'Transcript_Biotype': 'protein_coding',
#    'Transcript_End': 32973347,
#    'Transcript_Start': 32889611},
#   {'Ensembl_Gene_ID': 'ENSG00000139618',
#    'Ensembl_Transcript_ID': 'ENST00000530893',
#    'Transcript_Biotype': 'protein_coding',
#    'Transcript_End': 32907428,
#    'Transcript_Start': 32889642},
#   {'Ensembl_Gene_ID': 'ENSG00000139618',
#    'Ensembl_Transcript_ID': 'ENST00000528762',
#    'Transcript_Biotype': 'nonsense_mediated_decay',
#    'Transcript_End': 32953632,
#    'Transcript_Start': 32945108},
#   {'Ensembl_Gene_ID': 'ENSG00000139618',
#    'Ensembl_Transcript_ID': 'ENST00000470094',
#    'Transcript_Biotype': 'nonsense_mediated_decay',
#    'Transcript_End': 32972409,
#    'Transcript_Start': 32953977},
#   {'Ensembl_Gene_ID': 'ENSG00000139618',
#    'Ensembl_Transcript_ID': 'ENST00000533776',
#    'Transcript_Biotype': 'retained_intron',
#    'Transcript_End': 32972585,
#    'Transcript_Start': 32970946},
#   {'Ensembl_Gene_ID': 'ENSG00000139618',
#    'Ensembl_Transcript_ID': 'ENST00000544455',
#    'Transcript_Biotype': 'protein_coding',
#    'Transcript_End': 32973805,
#    'Transcript_Start': 32889617}]}

# %% [markdown]
# ## `/api/genes?offset=`
# ### No offset test

# %%
resp = requests.get("http://localhost:5000/api/genes")
print(resp.status_code)  # Should be 200
print(len(resp.json()))  # Should be 100
resp.json()  # Should contain list of genes
# Out:
# 200
# 5
# {'first': 1,
#  'items': [{'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '5',
#    'Ensembl_Gene_ID': 'BULK_100578',
#    'Gene_End': 52766024,
#    'Gene_Start': 52731258,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_100578'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_100668',
#    'Gene_End': 50856014,
#    'Gene_Start': 50808333,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_100668'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '5',
#    'Ensembl_Gene_ID': 'BULK_101016',
#    'Gene_End': 54314473,
#    'Gene_Start': 54307540,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_101016'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '8',
#    'Ensembl_Gene_ID': 'BULK_101179',
#    'Gene_End': 160503954,
#    'Gene_Start': 160484759,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_101179'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_101685',
#    'Gene_End': 136782472,
#    'Gene_Start': 136753756,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_101685'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '15',
#    'Ensembl_Gene_ID': 'BULK_102407',
#    'Gene_End': 151440900,
#    'Gene_Start': 151434551,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK
},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '12',
#    'Ensembl_Gene_ID': 'BULK_187598',
#    'Gene_End': 143396505,
#    'Gene_Start': 143365876,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_187598'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '20',
#    'Ensembl_Gene_ID': 'BULK_187970',
#    'Gene_End': 27386991,
#    'Gene_Start': 27366158,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_187970'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '21',
#    'Ensembl_Gene_ID': 'BULK_190148',
#    'Gene_End': 6668966,
#    'Gene_Start': 6621031,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_190148'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_190512',
#    'Gene_End': 27037140,
#    'Gene_Start': 27013971,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_190512'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_191778',
#    'Gene_End': 70504753,
#    'Gene_Start': 70484213,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_191778'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_193014',
#    'Gene_End': 65238515,
#    'Gene_Start': 65216187,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_193014'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '17',
#    'Ensembl_Gene_ID': 'BULK_193802',
#    'Gene_End': 24138083,
#    'Gene_Start': 24114826,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_193802'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '14',
#    'Ensembl_Gene_ID': 'BULK_194567',
#    'Gene_End': 89985681,
#    'Gene_Start': 89969231,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_194567'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_195252',
#    'Gene_End': 75912866,
#    'Gene_Start': 75886595,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_195252'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '21',
#    'Ensembl_Gene_ID': 'BULK_196222',
#    'Gene_End': 131967309,
#    'Gene_Start': 131946541,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_196222'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '2',
#    'Ensembl_Gene_ID': 'BULK_199699',
#    'Gene_End': 1838570,
#    'Gene_Start': 1796196,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_199699'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '2',
#    'Ensembl_Gene_ID': 'BULK_200241',
#    'Gene_End': 156799652,
#    'Gene_Start': 156789623,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_200241'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_200408',
#    'Gene_End': 22818994,
#    'Gene_Start': 22804145,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_200408'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '2',
#    'Ensembl_Gene_ID': 'BULK_202168',
#    'Gene_End': 109874735,
#    'Gene_Start': 109825114,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_202168'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '21',
#    'Ensembl_Gene_ID': 'BULK_203013',
#    'Gene_End': 23605378,
#    'Gene_Start': 23591131,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_203013'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '14',
#    'Ensembl_Gene_ID': 'BULK_203978',
#    'Gene_End': 150861285,
#    'Gene_Start': 150823793,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_203978'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_204033',
#    'Gene_End': 24978601,
#    'Gene_Start': 24973292,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_204033'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '13',
#    'Ensembl_Gene_ID': 'BULK_204393',
#    'Gene_End': 104023190,
#    'Gene_Start': 103986350,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_204393'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_205102',
#    'Gene_End': 151193079,
#    'Gene_Start': 151145386,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_205102'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '21',
#    'Ensembl_Gene_ID': 'BULK_206525',
#    'Gene_End': 118947201,
#    'Gene_Start': 118929831,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_206525'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_207538',
#    'Gene_End': 46150111,
#    'Gene_Start': 46121987,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_207538'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_208190',
#    'Gene_End': 169072099,
#    'Gene_Start': 169067862,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_208190'}],
#  'last': 100,
#  'next': '/api/genes?offset=100',
#  'prev': '/api/genes?offset=0'}

# %% [markdown]
# ## Offset test

# %%
resp = requests.get("http://localhost:5000/api/genes?offset=95")
print(resp.status_code)  # Should be 200
print(len(resp.json()))  # Should be 100
resp.json()  # Should contain the previous 5 genes in the beginning plus 95 new genes
# Out:
# 200
# 5
# {'first': 96,
#  'items': [{'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '13',
#    'Ensembl_Gene_ID': 'BULK_204393',
#    'Gene_End': 104023190,
#    'Gene_Start': 103986350,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_204393'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_205102',
#    'Gene_End': 151193079,
#    'Gene_Start': 151145386,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_205102'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '21',
#    'Ensembl_Gene_ID': 'BULK_206525',
#    'Gene_End': 118947201,
#    'Gene_Start': 118929831,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_206525'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_207538',
#    'Gene_End': 46150111,
#    'Gene_Start': 46121987,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_207538'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_208190',
#    'Gene_End': 169072099,
#    'Gene_Start': 169067862,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_208190'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '9',
#    'Ensembl_Gene_ID': 'BULK_208712',
#    'Gene_End': 98831263,
#    'Gene_Start': 98823659,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_208712'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '13',
#    'Ensembl_Gene_ID': 'BULK_208907',
#    'Gene_End': 19190027,
#    'Gene_Start': 19163866,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_208907'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_209188',
#    'Gene_End': 60123458,
#    'Gene_Start': 60103528,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_209188'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_209444',
#    'Gene_End': 154186720,
#    'Gene_Start': 154145562,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_209444'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '10',
#    'Ensembl_Gene_ID': 'BULK_209879',
#    'Gene_End': 101947797,
#    'Gene_Start': 101946684,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_

#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_320371'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '17',
#    'Ensembl_Gene_ID': 'BULK_321582',
#    'Gene_End': 173914656,
#    'Gene_Start': 173903041,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_321582'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_322283',
#    'Gene_End': 42203900,
#    'Gene_Start': 42195047,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_322283'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': 'X',
#    'Ensembl_Gene_ID': 'BULK_323312',
#    'Gene_End': 12216249,
#    'Gene_Start': 12186049,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_323312'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_323421',
#    'Gene_End': 11290111,
#    'Gene_Start': 11277506,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_323421'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_323719',
#    'Gene_End': 140215536,
#    'Gene_Start': 140193724,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_323719'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_328099',
#    'Gene_End': 126795271,
#    'Gene_Start': 126776101,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_328099'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '7',
#    'Ensembl_Gene_ID': 'BULK_328416',
#    'Gene_End': 176539970,
#    'Gene_Start': 176498738,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_328416'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '8',
#    'Ensembl_Gene_ID': 'BULK_328611',
#    'Gene_End': 132760160,
#    'Gene_Start': 132757046,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_328611'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_330551',
#    'Gene_End': 136237234,
#    'Gene_Start': 136228770,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_330551'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_331753',
#    'Gene_End': 186721456,
#    'Gene_Start': 186700069,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_331753'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '12',
#    'Ensembl_Gene_ID': 'BULK_332513',
#    'Gene_End': 87990246,
#    'Gene_Start': 87977282,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_332513'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_332674',
#    'Gene_End': 41356303,
#    'Gene_Start': 41324207,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_332674'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '14',
#    'Ensembl_Gene_ID': 'BULK_334897',
#    'Gene_End': 181537469,
#    'Gene_Start': 181533385,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_334897'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '8',
#    'Ensembl_Gene_ID': 'BULK_336593',
#    'Gene_End': 7038102,
#    'Gene_Start': 7009603,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_336593'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '19',
#    'Ensembl_Gene_ID': 'BULK_336986',
#    'Gene_End': 69015496,
#    'Gene_Start': 68985987,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_336986'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '12',
#    'Ensembl_Gene_ID': 'BULK_340239',
#    'Gene_End': 129807645,
#    'Gene_Start': 129801265,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_340239'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_341847',
#    'Gene_End': 110324058,
#    'Gene_Start': 110294403,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_341847'}],
#  'last': 195,
#  'next': '/api/genes?offset=195',
#  'prev': '/api/genes?offset=0'}

# %% [markdown]
# ## Edition
# ### Data insertion

# %%
"""
For POST requests (creation):
            JSON object containing gene data with required fields:
            - Ensemble_Gene_ID (str)
            - Chromosome_Name (str)
            - Band (str)
            - Gene_Start (int)
            - Gene_End (int)
"""
resp = requests.post("http://localhost:5000/api/genes/edit", json={
    "Ensemble_Gene_ID": "MANUAL_TEST_1",
    "Chromosome_Name": "1",
    "Band": "p36.33",
    "Gene_Start": 100000,
    "Gene_End": 100500
})
print(resp.status_code)  # Should be 201
resp.json()  # Should confirm creation
# Out:
# 409
# {'error': 'Conflict - Gene ID already exists'}

# %%
check_resp = requests.get("http://localhost:5000/api/genes/MANUAL_TEST_1")
print(check_resp.status_code)  # Should be 200
check_resp.json()  # Should contain the created gene information
# Out:
# 200
# {'Associated_Gene_Name': None,
#  'Band': 'q21.1',
#  'Chromosome_Name': '3',
#  'Ensembl_Gene_ID': 'MANUAL_TEST_1',
#  'Gene_End': 150800,
#  'Gene_Start': 150000,
#  'Strand': None,
#  'Transcript_count': 0,
#  'href': '/api/genes/MANUAL_TEST_1',
#  'parts': [],
#  'transcript': []}

# %% [markdown]
# ### Test with errors

# %%
"""
Dupplication test
"""
resp = requests.post("http://localhost:5000/api/genes/edit", json={
    "Ensemble_Gene_ID": "MANUAL_TEST_1",
    "Chromosome_Name": "1",
    "Band": "p36.33",
    "Gene_Start": 100000,
    "Gene_End": 100500
})
print(resp.status_code)  # Should be 201
resp.json()  # Should confirm creation
# Out:
# 409
# {'error': 'Conflict - Gene ID already exists'}

# %%
"""
Missing information test
"""

resp = requests.post("http://localhost:5000/api/genes/edit", json={
    "Ensemble_Gene_ID": "MANUAL_TEST_2",
    "Chromosome_Name": "1",
    # "Band" is missing
    "Gene_Start": 200000,
    "Gene_End": 200500
})
print(resp.status_code)  # Should be 400
resp.json()  # Should contain error message about missing 'Band' field
# Out:
# 400
# {'error': 'Bad Request'}

# %% [markdown]
# ### Data deletion

# %%
"""
Remove test
"""
resp = requests.delete("http://localhost:5000/api/genes/edit", json={
    "Ensemble_Gene_ID": "MANUAL_TEST_1"
})
print(resp.status_code)  # Should be 200
resp.json()  # Should confirm deletion
# Out:
# 200
# {'deleted': 'MANUAL_TEST_1'}

# %%
"""
Removal of non-existing gene test
"""
resp = requests.delete("http://localhost:5000/api/genes/edit", json={
    "Ensemble_Gene_ID": "NON_EXISTING_GENE"
})
print(resp.status_code)  # Should be 200 (according to instruction)
resp.json()  # Should confirm deletion anyway
# Out:
# 200
# {'deleted': 'NON_EXISTING_GENE'}

# %% [markdown]
# # Pour aller plus loin
# ## `/api/Genes`

# %%
resp = requests.get("http://localhost:5000/api/genes?offset=100")
print(resp.status_code)  # Should be 200
print(len(resp.json()))  # Should be 100
resp.json()  # Should contain list of genes
# Out:
# 200
# 5
# {'first': 101,
#  'items': [{'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '9',
#    'Ensembl_Gene_ID': 'BULK_208712',
#    'Gene_End': 98831263,
#    'Gene_Start': 98823659,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_208712'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '13',
#    'Ensembl_Gene_ID': 'BULK_208907',
#    'Gene_End': 19190027,
#    'Gene_Start': 19163866,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_208907'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_209188',
#    'Gene_End': 60123458,
#    'Gene_Start': 60103528,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_209188'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_209444',
#    'Gene_End': 154186720,
#    'Gene_Start': 154145562,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_209444'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '10',
#    'Ensembl_Gene_ID': 'BULK_209879',
#    'Gene_End': 101947797,
#    'Gene_Start': 101946684,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_209879'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '15',
#    'Ensembl_Gene_ID': 'BULK_210248',
#    'Gene_End': 17148429,
#    'Gene_Start': 17128961,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_210248'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '17',
#    'Ensembl_Gene_ID': 'BULK_214477',
#    'Gene_End': 156926957,
#    'Gene_Start': 156892083,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_214477'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_217600',
#    'Gene_End': 40972089,
#    'Gene_Start': 40933992,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_217600'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '14',
#    'Ensembl_Gene_ID': 'BULK_219540',
#    'Gene_End': 123637026,
#    'Gene_Start': 123603290,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_219540'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '4',
#    'Ensembl_Gene_ID': 'BULK_219848',
#    'Gene_End': 150914644,
#    'Gene_Start': 150876754,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_219848'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '5',
#    'Ensembl_Gene_ID': 'BULK_219919',
#    'Gene_End': 158887594,
#    'Gene_Start': 158875220,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_219919'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '6',
#    'Ensembl_Gene_ID': 'BULK_222006',
#    'Gene_End': 36696949,
#    'Gene_Start': 36655479,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_222006'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_224134',
#    'Gene_End': 20990361,
#    'Gene_Start': 20986686,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_224134'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_226327',
#    'Gene_End': 23900110,
#    'Gene_Start': 23869885,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_226327'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '14',
#    'Ensembl_Gene_ID': 'BULK_231189',
#    'Gene_End': 96853423,
#    'Gene_Start': 96833552,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_231189'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_232022',
#    'Gene_End': 18195053,
#    'Gene_Start': 18193474,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_232022'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '10',
#    'Ensembl_Gene_ID': 'BULK_232044',
#    'Gene_End': 39390144,
#    'Gene_Start': 39377691,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_232044'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_232245',
#    'Gene_End': 149172171,
#    'Gene_Start': 149168193,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_232245'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '6',
#    'Ensembl_Gene_ID': 'BULK_233630',
#    'Gene_End': 92731584,
#    'Gene_Start': 92703796,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_233630'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '8',
#    'Ensembl_Gene_ID': 'BULK_233637',
#    'Gene_End': 122200772,
#    'Gene_Start': 122175179,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_233637'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '13',
#    'Ensembl_Gene_ID': 'BULK_234507',
#    'Gene_End': 153873948,
#    'Gene_Start': 153824185,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_234507'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_234600',
#    'Gene_End': 185670943,
#    'Gene_Start': 185640270,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_234600'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '17',
#    'Ensembl_Gene_ID': 'BULK_234865',
#    'Gene_End': 171701077,
#    'Gene_Start': 171667186,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_234865'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_236287',
#    'Gene_End': 136539462,
#    'Gene_Start': 136496559,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_236287'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': 'X',
#    'Ensembl_Gene_ID': 'BULK
},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '10',
#    'Ensembl_Gene_ID': 'BULK_290452',
#    'Gene_End': 40025367,
#    'Gene_Start': 40017948,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_290452'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_290760',
#    'Gene_End': 60881145,
#    'Gene_Start': 60840011,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_290760'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '19',
#    'Ensembl_Gene_ID': 'BULK_291031',
#    'Gene_End': 135468471,
#    'Gene_Start': 135424205,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_291031'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_291737',
#    'Gene_End': 11274882,
#    'Gene_Start': 11236265,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_291737'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_294598',
#    'Gene_End': 182037504,
#    'Gene_Start': 181996366,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_294598'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_296326',
#    'Gene_End': 86235376,
#    'Gene_Start': 86233230,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_296326'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '7',
#    'Ensembl_Gene_ID': 'BULK_299089',
#    'Gene_End': 146754899,
#    'Gene_Start': 146710145,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_299089'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': 'X',
#    'Ensembl_Gene_ID': 'BULK_299350',
#    'Gene_End': 77773258,
#    'Gene_Start': 77753677,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_299350'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_299674',
#    'Gene_End': 10849413,
#    'Gene_Start': 10830108,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_299674'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_301040',
#    'Gene_End': 129313416,
#    'Gene_Start': 129303509,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_301040'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '21',
#    'Ensembl_Gene_ID': 'BULK_302347',
#    'Gene_End': 158202502,
#    'Gene_Start': 158186116,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_302347'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '16',
#    'Ensembl_Gene_ID': 'BULK_305891',
#    'Gene_End': 12267434,
#    'Gene_Start': 12240569,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_305891'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_306943',
#    'Gene_End': 170329919,
#    'Gene_Start': 170296957,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_306943'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '6',
#    'Ensembl_Gene_ID': 'BULK_307486',
#    'Gene_End': 120016378,
#    'Gene_Start': 120004816,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_307486'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p36.33',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_307806',
#    'Gene_End': 158151163,
#    'Gene_Start': 158111827,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_307806'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_308556',
#    'Gene_End': 160997081,
#    'Gene_Start': 160986352,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_308556'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '19',
#    'Ensembl_Gene_ID': 'BULK_311189',
#    'Gene_End': 166163394,
#    'Gene_Start': 166119850,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_311189'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '10',
#    'Ensembl_Gene_ID': 'BULK_314231',
#    'Gene_End': 31307630,
#    'Gene_Start': 31272426,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_314231'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_315715',
#    'Gene_End': 177218420,
#    'Gene_Start': 177175900,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_315715'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_318989',
#    'Gene_End': 191136429,
#    'Gene_Start': 191124256,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_318989'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_320371',
#    'Gene_End': 110784297,
#    'Gene_Start': 110752166,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_320371'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '17',
#    'Ensembl_Gene_ID': 'BULK_321582',
#    'Gene_End': 173914656,
#    'Gene_Start': 173903041,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_321582'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_322283',
#    'Gene_End': 42203900,
#    'Gene_Start': 42195047,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_322283'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': 'X',
#    'Ensembl_Gene_ID': 'BULK_323312',
#    'Gene_End': 12216249,
#    'Gene_Start': 12186049,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_323312'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q31.2',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_323421',
#    'Gene_End': 11290111,
#    'Gene_Start': 11277506,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_323421'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_323719',
#    'Gene_End': 140215536,
#    'Gene_Start': 140193724,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_323719'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '1',
#    'Ensembl_Gene_ID': 'BULK_328099',
#    'Gene_End': 126795271,
#    'Gene_Start': 126776101,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_328099'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '7',
#    'Ensembl_Gene_ID': 'BULK_328416',
#    'Gene_End': 176539970,
#    'Gene_Start': 176498738,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_328416'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '8',
#    'Ensembl_Gene_ID': 'BULK_328611',
#    'Gene_End': 132760160,
#    'Gene_Start': 132757046,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_328611'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '11',
#    'Ensembl_Gene_ID': 'BULK_330551',
#    'Gene_End': 136237234,
#    'Gene_Start': 136228770,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_330551'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '22',
#    'Ensembl_Gene_ID': 'BULK_331753',
#    'Gene_End': 186721456,
#    'Gene_Start': 186700069,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_331753'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p21.1',
#    'Chromosome_Name': '12',
#    'Ensembl_Gene_ID': 'BULK_332513',
#    'Gene_End': 87990246,
#    'Gene_Start': 87977282,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_332513'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '3',
#    'Ensembl_Gene_ID': 'BULK_332674',
#    'Gene_End': 41356303,
#    'Gene_Start': 41324207,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_332674'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': '14',
#    'Ensembl_Gene_ID': 'BULK_334897',
#    'Gene_End': 181537469,
#    'Gene_Start': 181533385,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_334897'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '8',
#    'Ensembl_Gene_ID': 'BULK_336593',
#    'Gene_End': 7038102,
#    'Gene_Start': 7009603,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_336593'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '19',
#    'Ensembl_Gene_ID': 'BULK_336986',
#    'Gene_End': 69015496,
#    'Gene_Start': 68985987,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_336986'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': '12',
#    'Ensembl_Gene_ID': 'BULK_340239',
#    'Gene_End': 129807645,
#    'Gene_Start': 129801265,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_340239'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_341847',
#    'Gene_End': 110324058,
#    'Gene_Start': 110294403,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_341847'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q34',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_343886',
#    'Gene_End': 83701967,
#    'Gene_Start': 83654079,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_343886'},
#   {'Associated_Gene_Name': None,
#    'Band': 'p15.2',
#    'Chromosome_Name': 'Y',
#    'Ensembl_Gene_ID': 'BULK_344251',
#    'Gene_End': 98045050,
#    'Gene_Start': 98039440,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_344251'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_347696',
#    'Gene_End': 52239398,
#    'Gene_Start': 52212064,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_347696'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q22.3',
#    'Chromosome_Name': '18',
#    'Ensembl_Gene_ID': 'BULK_349973',
#    'Gene_End': 28843453,
#    'Gene_Start': 28832110,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_349973'},
#   {'Associated_Gene_Name': None,
#    'Band': 'q13.2',
#    'Chromosome_Name': '2',
#    'Ensembl_Gene_ID': 'BULK_349979',
#    'Gene_End': 93964255,
#    'Gene_Start': 93914707,
#    'Strand': None,
#    'Transcript_count': 0,
#    'href': '/api/genes/BULK_349979'}],
#  'last': 200,
#  'next': '/api/genes?offset=200',
#  'prev': '/api/genes?offset=0'}

# %% [markdown]
# ## Allowing data list creation

# %%
import random

"""
Let's create multiple genes at once
"""
bands = ["p36.33", "p21.1", "q13.2", "q22.3", "p15.2", "q31.2", "q34"]
chromosomes = [str(i) for i in range(1, 23)] + ["X", "Y"]

genes_data = []

for _ in range(300):
    gene_start = random.randint(1_000_000, 200_000_000)
    gene_end = gene_start + random.randint(500, 50_000)  # entre 0.5 kb et 50 kb
    
    gene = {
        "Ensemble_Gene_ID": f"BULK_{random.randint(100000, 999999)}",
        "Chromosome_Name": random.choice(chromosomes),
        "Band": random.choice(bands),
        "Gene_Start": gene_start,
        "Gene_End": gene_end
    }
    genes_data.append(gene)

print(f"Prepared {len(genes_data)} genes for bulk creation.")
# Out:
# Prepared 300 genes for bulk creation.

# %%
resp = requests.post("http://localhost:5000/api/genes/edit", json=genes_data)
print(resp.status_code)  # Should be 201
resp.json()  # Should contain list of created gene URLs
# Out:
# 201
# {'bulks_count': 3,
#  'created': ['/api/genes/BULK_843175',
#   '/api/genes/BULK_917217',
#   '/api/genes/BULK_703257',
#   '/api/genes/BULK_190076',
#   '/api/genes/BULK_900401',
#   '/api/genes/BULK_666410',
#   '/api/genes/BULK_897294',
#   '/api/genes/BULK_974179',
#   '/api/genes/BULK_644803',
#   '/api/genes/BULK_812477',
#   '/api/genes/BULK_940747',
#   '/api/genes/BULK_763255',
#   '/api/genes/BULK_830815',
#   '/api/genes/BULK_373646',
#   '/api/genes/BULK_437032',
#   '/api/genes/BULK_941985',
#   '/api/genes/BULK_217656',
#   '/api/genes/BULK_860546',
#   '/api/genes/BULK_899129',
#   '/api/genes/BULK_602112',
#   '/api/genes/BULK_763785',
#   '/api/genes/BULK_788666',
#   '/api/genes/BULK_362331',
#   '/api/genes/BULK_147487',
#   '/api/genes/BULK_126825',
#   '/api/genes/BULK_987039',
#   '/api/genes/BULK_984555',
#   '/api/genes/BULK_368849',
#   '/api/genes/BULK_874190',
#   '/api/genes/BULK_811557',
#   '/api/genes/BULK_633789',
#   '/api/genes/BULK_199039',
#   '/api/genes/BULK_915325',
#   '/api/genes/BULK_546356',
#   '/api/genes/BULK_608641',
#   '/api/genes/BULK_757351',
#   '/api/genes/BULK_104363',
#   '/api/genes/BULK_103489',
#   '/api/genes/BULK_429668',
#   '/api/genes/BULK_884324',
#   '/api/genes/BULK_305645',
#   '/api/genes/BULK_703496',
#   '/api/genes/BULK_734960',
#   '/api/genes/BULK_903773',
#   '/api/genes/BULK_208856',
#   '/api/genes/BULK_720026',
#   '/api/genes/BULK_355268',
#   '/api/genes/BULK_114887',
#   '/api/genes/BULK_415161',
#   '/api/genes/BULK_974835',
#   '/api/genes/BULK_348547',
#   '/api/genes/BULK_210063',
#   '/api/genes/BULK_893909',
#   '/api/genes/BULK_972027',
#   '/api/genes/BULK_687234',
#   '/api/genes/BULK_240387',
#   '/api/genes/BULK_410730',
#   '/api/genes/BULK_357729',
#   '/api/genes/BULK_196376',
#   '/api/genes/BULK_601445',
#   '/api/genes/BULK_490792',
#   '/api/genes/BULK_919282',
#   '/api/genes/BULK_508253',
#   '/api/genes/BULK_328226',
#   '/api/genes/BULK_145048',
#   '/api/genes/BULK_522511',
#   '/api/genes/BULK_196669',
#   '/api/genes/BULK_204602',
#   '/api/genes/BULK_433788',
#   '/api/genes/BULK_943278',
#   '/api/genes/BULK_588456',
#   '/api/genes/BULK_744794',
#   '/api/genes/BULK_717532',
#   '/api/genes/BULK_755684',
#   '/api/genes/BULK_303732',
#   '/api/genes/BULK_658712',
#   '/api/genes/BULK_752508',
#   '/api/genes/BULK_911992',
#   '/api/genes/BULK_546484',
#   '/api/genes/BULK_647558',
#   '/api/genes/BULK_529545',
#   '/api/genes/BULK_200801',
#   '/api/genes/BULK_897091',
#   '/api/genes/BULK_838211',
#   '/api/genes/BULK_619377',
#   '/api/genes/BULK_217899',
#   '/api/genes/BULK_783266',
#   '/api/genes/BULK_871825',
#   '/api/genes/BULK_649069',
#   '/api/genes/BULK_561677',
#   '/api/genes/BULK_966670',
#   '/api/genes/BULK_571496',
#   '/api/genes/BULK_110355',
#   '/api/genes/BULK_349585',
#   '/api/genes/BULK_968489',
#   '/api/genes/BULK_816054',
#   '/api/genes/BULK_863497',
#   '/api/genes/BULK_119203',
#   '/api/genes/BULK_512340',
#   '/api/genes/BULK_819135',
#   '/api/genes/BULK_120232',
#   '/api/genes/BULK_913220',
#   '/api/genes/BULK_228967',
#   '/api/genes/BULK_702059',
#   '/api/genes/BULK_735832',
#   '/api/genes/BULK_938489',
#   '/api/genes/BULK_423612',
#   '/api/genes/BULK_416993',
#   '/api/genes/BULK_414828',
#   '/api/genes/BULK_220352',
#   '/api/genes/BULK_987639',
#   '/api/genes/BULK_416427',
#   '/api/genes/BULK_204058',
#   '/api/genes/BULK_948786',
#   '/api/genes/BULK_611342',
#   '/api/genes/BULK_618160',
#   '/api/genes/BULK_552725',
#   '/api/genes/BULK_607908',
#   '/api/genes/BULK_650241',
#   '/api/genes/BULK_440921',
#   '/api/genes/BULK_455727',
#   '/api/genes/BULK_496544',
#   '/api/genes/BULK_508778',
#   '/api/genes/BULK_276460',
#   '/api/genes/BULK_336188',
#   '/api/genes/BULK_340913',
#   '/api/genes/BULK_330942',
#   '/api/genes/BULK_406837',
#   '/api/genes/BULK_345620',
#   '/api/genes/BULK_278357',
#   '/api/genes/BULK_495582',
#   '/api/genes/BULK_636637',
#   '/api/genes/BULK_968855',
#   '/api/genes/BULK_988626',
#   '/api/genes/BULK_807746',
#   '/api/genes/BULK_310069',
#   '/api/genes/BULK_484721',
#   '/api/genes/BULK_941867',
#   '/api/genes/BULK_999661',
#   '/api/genes/BULK_250718',
#   '/api/genes/BULK_813988',
#   '/api/genes/BULK_945451',
#   '/api/genes/BULK_459110',
#   '/api/genes/BULK_415482',
#   '/api/genes/BULK_361087',
#   '/api/genes/BULK_943715',
#   '/api/genes/BULK_127558',
#   '/api/genes/BULK_903211',
#   '/api/genes/BULK_902880',
#   '/api/genes/BULK_152677',
#   '/api/genes/BULK_347064',
#   '/api/genes/BULK_952632',
#   '/api/genes/BULK_904011',
#   '/api/genes/BULK_380982',
#   '/api/genes/BULK_474343',
#   '/api/genes/BULK_987232',
#   '/api/genes/BULK_683380',
#   '/api/genes/BULK_171331',
#   '/api/genes/BULK_953783',
#   '/api/genes/BULK_545961',
#   '/api/genes/BULK_203557',
#   '/api/genes/BULK_127123',
#   '/api/genes/BULK_578337',
#   '/api/genes/BULK_941120',
#   '/api/genes/BULK_422767',
#   '/api/genes/BULK_636753',
#   '/api/genes/BULK_550550',
#   '/api/genes/BULK_985727',
#   '/api/genes/BULK_350154',
#   '/api/genes/BULK_707944',
#   '/api/genes/BULK_976328',
#   '/api/genes/BULK_189199',
#   '/api/genes/BULK_257122',
#   '/api/genes/BULK_464304',
#   '/api/genes/BULK_215947',
#   '/api/genes/BULK_629303',
#   '/api/genes/BULK_520740',
#   '/api/genes/BULK_226677',
#   '/api/genes/BULK_621550',
#   '/api/genes/BULK_680202',
#   '/api/genes/BULK_725886',
#   '/api/genes/BULK_811851',
#   '/api/genes/BULK_149076',
#   '/api/genes/BULK_722229',
#   '/api/genes/BULK_571285',
#   '/api/genes/BULK_961734',
#   '/api/genes/BULK_553185',
#   '/api/genes/BULK_775154',
#   '/api/genes/BULK_450284',
#   '/api/genes/BULK_701639',
#   '/api/genes/BULK_761810',
#   '/api/genes/BULK_942437',
#   '/api/genes/BULK_966313',
#   '/api/genes/BULK_379689',
#   '/api/genes/BULK_102972',
#   '/api/genes/BULK_498884',
#   '/api/genes/BULK_769533',
#   '/api/genes/BULK_379878',
#   '/api/genes/BULK_451974',
#   '/api/genes/BULK_655043',
#   '/api/genes/BULK_580901',
#   '/api/genes/BULK_807148',
#   '/api/genes/BULK_948651',
#   '/api/genes/BULK_300895',
#   '/api/genes/BULK_667187',
#   '/api/genes/BULK_621604',
#   '/api/genes/BULK_569232',
#   '/api/genes/BULK_540950',
#   '/api/genes/BULK_930338',
#   '/api/genes/BULK_534506',
#   '/api/genes/BULK_656997',
#   '/api/genes/BULK_973437',
#   '/api/genes/BULK_314419',
#   '/api/genes/BULK_172502',
#   '/api/genes/BULK_714139',
#   '/api/genes/BULK_310253',
#   '/api/genes/BULK_474151',
#   '/api/genes/BULK_633118',
#   '/api/genes/BULK_342061',
#   '/api/genes/BULK_737379',
#   '/api/genes/BULK_906843',
#   '/api/genes/BULK_738062',
#   '/api/genes/BULK_336615',
#   '/api/genes/BULK_117380',
#   '/api/genes/BULK_106989',
#   '/api/genes/BULK_901581',
#   '/api/genes/BULK_565382',
#   '/api/genes/BULK_787352',
#   '/api/genes/BULK_617477',
#   '/api/genes/BULK_359705',
#   '/api/genes/BULK_474853',
#   '/api/genes/BULK_572725',
#   '/api/genes/BULK_381010',
#   '/api/genes/BULK_990697',
#   '/api/genes/BULK_666919',
#   '/api/genes/BULK_855425',
#   '/api/genes/BULK_896265',
#   '/api/genes/BULK_984925',
#   '/api/genes/BULK_219120',
#   '/api/genes/BULK_327767',
#   '/api/genes/BULK_740730',
#   '/api/genes/BULK_786275',
#   '/api/genes/BULK_926430',
#   '/api/genes/BULK_955180',
#   '/api/genes/BULK_540973',
#   '/api/genes/BULK_809821',
#   '/api/genes/BULK_972579',
#   '/api/genes/BULK_367619',
#   '/api/genes/BULK_797928',
#   '/api/genes/BULK_408839',
#   '/api/genes/BULK_839955',
#   '/api/genes/BULK_886352',
#   '/api/genes/BULK_432906',
#   '/api/genes/BULK_951718',
#   '/api/genes/BULK_409070',
#   '/api/genes/BULK_734513',
#   '/api/genes/BULK_684387',
#   '/api/genes/BULK_658964',
#   '/api/genes/BULK_350052',
#   '/api/genes/BULK_940126',
#   '/api/genes/BULK_650661',
#   '/api/genes/BULK_993485',
#   '/api/genes/BULK_475831',
#   '/api/genes/BULK_921637',
#   '/api/genes/BULK_155232',
#   '/api/genes/BULK_189650',
#   '/api/genes/BULK_953384',
#   '/api/genes/BULK_658028',
#   '/api/genes/BULK_153819',
#   '/api/genes/BULK_322368',
#   '/api/genes/BULK_207917',
#   '/api/genes/BULK_778461',
#   '/api/genes/BULK_715289',
#   '/api/genes/BULK_846074',
#   '/api/genes/BULK_702346',
#   '/api/genes/BULK_839093',
#   '/api/genes/BULK_895968',
#   '/api/genes/BULK_800502',
#   '/api/genes/BULK_884017',
#   '/api/genes/BULK_877971',
#   '/api/genes/BULK_401849',
#   '/api/genes/BULK_808387',
#   '/api/genes/BULK_877069',
#   '/api/genes/BULK_886758',
#   '/api/genes/BULK_538762',
#   '/api/genes/BULK_897053',
#   '/api/genes/BULK_638485',
#   '/api/genes/BULK_399506',
#   '/api/genes/BULK_427571',
#   '/api/genes/BULK_391795',
#   '/api/genes/BULK_667959',
#   '/api/genes/BULK_630826',
#   '/api/genes/BULK_661485',
#   '/api/genes/BULK_881273',
#   '/api/genes/BULK_475536',
#   '/api/genes/BULK_416869',
#   '/api/genes/BULK_388559',
#   '/api/genes/BULK_133449',
#   '/api/genes/BULK_375252',
#   '/api/genes/BULK_234201']}

# %% [markdown]
# ## Put method

# %%
"""
We create an object to update an existing gene
"""
resp = requests.post("http://localhost:5000/api/genes/edit", json={
    "Ensemble_Gene_ID": "MANUAL_TEST_1",
    "Chromosome_Name": "1",
    "Band": "p36.33",
    "Gene_Start": 100000,
    "Gene_End": 100500
})
print(resp.status_code)  # Should be 201
resp.json()  # Should confirm creation
# Out:
# 201
# {'created': '/api/genes/MANUAL_TEST_1'}

# %%
resp = requests.get("http://localhost:5000/api/genes/MANUAL_TEST_1")
print(resp.status_code)  # Should be 200
resp.json()  # Should contain the created gene information
# Out:
# 200
# {'Associated_Gene_Name': None,
#  'Band': 'p36.33',
#  'Chromosome_Name': '1',
#  'Ensembl_Gene_ID': 'MANUAL_TEST_1',
#  'Gene_End': 100500,
#  'Gene_Start': 100000,
#  'Strand': None,
#  'Transcript_count': 0,
#  'href': '/api/genes/MANUAL_TEST_1',
#  'parts': [],
#  'transcript': []}

# %%
resp = requests.put("http://localhost:5000/api/genes/MANUAL_TEST_1", json={
    "Ensemble_Gene_ID": "MANUAL_TEST_1",
    "Chromosome_Name": "3",
    "Band": "q21.1",
    "Gene_Start": 150000,
    "Gene_End": 150800
})
print(resp.status_code)  # Should be 200
resp.json()  # Should confirm update
# Out:
# 200
# {'edited': '/api/genes/MANUAL_TEST_1'}

# %%
resp = requests.get("http://localhost:5000/api/genes/MANUAL_TEST_1")
print(resp.status_code)  # Should be 200
resp.json()  # Should contain the created gene information
# Out:
# 200
# {'Associated_Gene_Name': None,
#  'Band': 'q21.1',
#  'Chromosome_Name': '3',
#  'Ensembl_Gene_ID': 'MANUAL_TEST_1',
#  'Gene_End': 150800,
#  'Gene_Start': 150000,
#  'Strand': None,
#  'Transcript_count': 0,
#  'href': '/api/genes/MANUAL_TEST_1',
#  'parts': [],
#  'transcript': []}
